# %% [markdown]
# # Nama  :PARDI OCTAVIANDO
# # NIM   : 122450132
# # KELAS : RC
# # TUGAS VISUALISASI DATA PERTEMUAN 5
# # File csv : Spotify Most Streamed Songs
# ## Link Csv : https://www.kaggle.com/datasets/abdulszz/spotify-most-streamed-songs

# %% [markdown]
# # Pertanyaan / Soal :
#
# Dalam methodologi, langkah pertama yang perlu dlilakukan dalam pengembangan visualisasi adalah mendefinisikan tujuan dan parameter (memperhatikan user, fungsi dan tone). Berdasarkan hal tersebut maka tugas anda adalah:
# 1. Tentukan data yang akan anda gunakan dalam visualisasi
# 2. Berdasarkan data yang anda pilih tentukan tujuan, user, fungsi dan tone (jika ada) yang sesuai dengan visualisasi yang akan anda buat
# 3. Buatlah visualisasi dengan mengunakan library python seperti matplotlib, seaborn atau tools lain

# %% [markdown]
# ## 1. Tentukan data yang akan anda gunakan dalam visualisasi
# ### Jawab:
#
# Dataset ini berisi informasi tentang lagu-lagu yang paling banyak diputar di Spotify, dengan kolom-kolom seperti judul lagu, nama artis, tahun rilis, jumlah streaming, serta beberapa fitur audio seperti danceability, energy, dan valence. Beberapa kolom kunci yang akan digunakan untuk visualisasi adalah:
#
# 1. track_name (judul lagu)
# 2. artist(s)_name (nama artis)
# 3. eleased_year (tahun rilis)
# 4. streams (jumlah streaming)
# 5. danceability_%, energy_%, dan valence_% (karakteristik audio)

# %% [markdown]
# ## 2. Berdasarkan data yang anda pilih tentukan tujuan, user, fungsi dan tone (jika ada) yang sesuai dengan visualisasi yang akan anda buat
# ### Jawab:
#
# A. Tujuan:
# Memberikan visualisasi yang menggambarkan pola perilaku lagu-lagu yang paling banyak diputar di Spotify, seperti distribusi jumlah streaming berdasarkan artis, tahun rilis, dan karakteristik audio.
#
# B. User:
# Visualisasi ini dapat digunakan oleh peneliti musik, penggemar musik, dan profesional di industri musik untuk memahami tren lagu-lagu populer.
#
# C. Fungsi:
# Membantu pengguna menganalisis lagu-lagu yang sedang populer dengan memperlihatkan karakteristik audio yang mempengaruhi jumlah streaming, serta tren musik dari waktu ke waktu.
#
# D. Tone:
# Informasional dan analitis, dengan tampilan visual yang bersih dan mudah dipahami.

# %% [markdown]
# ##3. Buatlah visualisasi dengan mengunakan library python seperti matplotlib, seaborn atau tools lain
#
# ### Jawab:
#
# Mari kita gunakan Plotly untuk membuat visualisasi interaktif. Saya akan membuat beberapa visualisasi yang lebih rinci, seperti:
#
# 1. Histogram interaktif dari distribusi jumlah streaming berdasarkan tahun rilis.
# 2. Bubble chart interaktif yang menunjukkan hubungan antara jumlah streaming dan karakteristik audio (danceability, energy, valence).

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %%
import pandas as pd
import plotly.express as px

# Memuat data dari jalur file CSV yang benar
file_path = '/content/Spotify Most Streamed Songs.csv'
data = pd.read_csv(file_path)

# Convert 'streams' column to numeric, handling errors by coercing to NaN
data['streams'] = pd.to_numeric(data['streams'], errors='coerce')

# 1. Histogram interaktif dari distribusi jumlah streaming berdasarkan tahun rilis
fig1 = px.histogram(data, x='released_year', y='streams', title='Distribusi Jumlah Streaming Berdasarkan Tahun Rilis',
                   labels={'released_year': 'Tahun Rilis', 'streams': 'Jumlah Streaming'},
                   color='released_year',
                   hover_data=['track_name', 'artist(s)_name'],
                   nbins=15, height=400)
fig1.show()

# 2. Bubble chart interaktif untuk melihat hubungan antara danceability, energy, valence, dan jumlah streaming
# Filter out NaN values from 'streams' column before creating the scatter plot
filtered_data = data.dropna(subset=['streams'])  # Drop rows with NaN in 'streams'

fig2 = px.scatter(filtered_data, x='danceability_%', y='streams',  # Use filtered_data
                  size='streams', color='valence_%',
                  hover_name='track_name', hover_data=['artist(s)_name'],
                  title='Perbandingan Danceability, Energy, Valence dengan Jumlah Streaming',
                  labels={'danceability_%': 'Danceability (%)', 'streams': 'Jumlah Streaming', 'valence_%': 'Valence (%)'},
                  size_max=60)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="457225f9-f28f-4a74-a9e6-90e9728abff0" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("457225f9-f28f-4a74-a9e6-90e9728abff0")) {                    Plotly.newPlot(                        "457225f9-f28f-4a74-a9e6-90e9728abff0",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Tahun Rilis=%{x}\u003cbr\u003esum of Jumlah Streaming=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2023","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2023","nbinsx":15,"offsetgroup":"2023","orientation":"v","showlegend":true,"x":[2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023],"xaxis":"x","y":[141381703.0,133716286.0,140003974.0,303236322.0,183706234.0,725980112.0,58149378.0,95217315.0,553634067.0,505671438.0,58255150.0,1316855716.0,387570742.0,496795686.0,30546883.0,335222234.0,363369738.0,86444842.0,52135248.0,200647221.0,115364561.0,78300654.0,61245289.0,429829812.0,127408954.0,22581161.0,52294266.0,618990393.0,123122413.0,188933502.0,176553476.0,354495408.0,65156199.0,518745108.0,107753850.0,177740666.0,153372011.0,57876440.0,256483385.0,16011326.0,111947664.0,156338624.0,357925728.0,14780425.0,39578178.0,54266102.0,43857627.0,39709092.0,39228929.0,223633238.0,157058870.0,95131998.0,250305248.0,144565150.0,127567540.0,118482347.0,172825906.0,29562220.0,39058561.0,36912123.0,201660859.0,248088961.0,90839753.0,55842345.0,211050784.0,66902503.0,96273746.0,430977451.0,721975598.0,109276132.0,54225632.0,81102253.0,11956641.0,11599388.0,255932395.0,31873544.0,95053634.0,233801632.0,142095275.0,436027885.0,94186466.0,143573775.0,307370144.0,47956378.0,30343206.0,57312735.0,86773632.0,133753727.0,123124076.0,64533040.0,65496046.0,68616963.0,161460990.0,70106975.0,113509496.0,89933133.0,43522589.0,232896922.0,37126685.0,195576623.0,46142772.0,127026613.0,60350538.0,76767396.0,46065667.0,39666245.0,138517666.0,51985779.0,57945987.0,115010040.0,175097833.0,57089066.0,32761689.0,153454328.0,217672943.0,71573339.0,24975653.0,145458418.0,50847624.0,39893489.0,92035115.0,118810253.0,77233241.0,206399629.0,117747907.0,266624541.0,139681964.0,123132751.0,162887075.0,91221625.0,96180277.0,104992946.0,147290338.0,76910644.0,207033255.0,61105704.0,168448603.0,34502215.0,173627354.0,90025258.0,146409671.0,95816024.0,117206995.0,100409613.0,80758350.0,58473276.0,52722996.0,77377503.0,67070410.0,116334601.0,165584767.0,68216992.0,149778242.0,116599790.0,88791109.0,125917280.0,105062254.0,95623148.0,144584800.0,166570053.0,83021468.0,58890931.0,81419389.0,93438910.0,56533272.0,175399345.0,147538971.0,34450974.0,32526947.0,124988687.0,103787664.0,134255790.0,152850295.0,120972253.0,107642809.0],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Tahun Rilis=%{x}\u003cbr\u003esum of Jumlah Streaming=%{y}\u003cextra\u003e\u003c\ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ecb377e-dc4e-4c0b-b3c5-03ab7244b40d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ecb377e-dc4e-4c0b-b3c5-03ab7244b40d")) {                    Plotly.newPlot(                        "4ecb377e-dc4e-4c0b-b3c5-03ab7244b40d",                        [{"customdata":[["Latto, Jung Kook"],["Myke Towers"],["Olivia Rodrigo"],["Taylor Swift"],["Bad Bunny"],["Dave, Central Cee"],["Eslabon Armado, Peso Pluma"],["Quevedo"],["Gunna"],["Peso Pluma, Yng Lvcas"],["Bad Bunny, Grupo Frontera"],["NewJeans"],["Miley Cyrus"],["David Kushner"],["Harry Styles"],["SZA"],["Fifty Fifty"],["Billie Eilish"],["Feid, Young Miko"],["Jimin"],["Gabito Ballesteros, Junior H, Peso Pluma"],["Taylor Swift"],["Arctic Monkeys"],["Bizarrap, Peso Pluma"],["The Weeknd, Madonna, Playboi Carti"],["Fuerza Regida"],["R\u00ef\u00bf\u00bd\u00ef\u00bf\u00bdma, Selena G"],["Tainy, Bad Bunny"],["Morgan Wallen"],["Dua Lipa"],["Troye Sivan"],["Peso Pluma, Grupo Frontera"],["The Weeknd, 21 Savage, Metro Boomin"],["Taylor Swift"],["Karol G, Shakira"],["Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk"],["Yahritza Y Su Esencia, Grupo Frontera"],["Taylor Swift"],["Taylor Swift"],["Fuerza Regida"],["Junior H, Peso Pluma"],["Post Malone, Swae Lee"],["Bebe Rexha, David Guetta"],["Tyler, The Creator, Kali Uchis"],["Nicki Minaj, Aqua, Ice Spice"],["Miley Cyrus"],["OneRepublic"],["The Weeknd"],["The Weeknd, Daft Punk"],["Ariana Grande, The Weeknd"],["Feid, Myke Towers, Sky Rompiendo"],["David Guetta, Anne-Marie, Coi Leray"],["Karol G"],["Peggy Gou"],["Tom Odell"],["The Weeknd"],["Kali Uchis"],["Manuel Turizo"],["Karol G"],["Taylor Swift"],["dennis, MC Kevin o Chris"],["PinkPantheress, Ice Spice"],["Charlie Puth, BTS, Jung Kook"],["Rauw Alejandro, ROSAL\u00ef\u00bf\u00bd"],["Ozuna, Feid"],["Chris Molitor"],["Taylor Swift"],["Libianca"],["Post Malone"],["Taylor Swift"],["Rauw Alejandro, Bizarrap"],["Glass Animals"],["JVKE"],["The Neighbourhood"],["Bizarrap, Quevedo"],["Coldplay"],["d4vd"],["Sam Smith, Kim Petras"],["Yandel, Feid"],["Maria Becerra"],["Vance Joy"],["Em Beihold, Stephen Sanchez"],["Mc Livinho, DJ Matt D"],["Taylor Swift"],["Justin Bieber, The Kid Laroi"],["Marshmello, Manuel Turizo"],["Lewis Capaldi"],["Chencho Corleone, Bad Bunny"],["Jain"],["Ayparia, unxbected"],["Luke Combs"],["Doechii"],["Bad Bunny, Eladio Carrion"],["Taylor Swift"],["Jung Kook"],["J. Cole, Lil Durk"],["Lana Del Rey"],["SZA"],["Lana Del Rey"],["BTS"],["Taylor Swift"],["Future, Metro Boomin, Don Toliver"],["Post Malone"],["Eminem"],["NewJeans"],["Carin Leon"],["Dua Lipa, Elton John, Pnau"],["Ruth B."],["Imagine Dragons"],["Adele"],["Kendrick Lamar, Jay Rock"],["Anggi Marito"],["Jasiel Nu\u00ef\u00bf\u00bd\u00ef\u00bf\u00bdez, Peso P"],["Taylor Swift"],["Tears For Fears"],["J. Cole"],["Loreen"],["Taiu, Milo j"],["Sebastian Yatra, Manuel Turizo, Be\u00ef\u00bf\u00bd\u00ef"],["Taylor Swift"],["Junior H, Peso Pluma"],["Calvin Harris, Ellie Goulding"],["Sabrina Carpenter"],["Carin Leon, Grupo Frontera"],["Peso Pluma"],["Feid"],["Ray Dalton, Ryan Lewis, Macklemore"],["Harry Styles"],["Billie Eilish, Khalid"],["Rauw Alejandro, Bizarrap"],["(G)I-DLE"],["NewJeans"],["Lana Del Rey"],["Shakira, Bizarrap"],["Arctic Monkeys"],["Swae Lee, A Boogie Wit da Hoodie, Metro Boomin, NAV"],["Travis Scott, Young Thug, Metro Boomin"],["Sachin-Jigar, Shadab Faridi, Altamash Faridi, Amitabh Bhattacharya, Varun Jain"],["Ed Sheeran"],["d4vd"],["Imagine Dragons"],["Veigh, Bvga Beatz, Supernova Ent, Prod Malax"],["Mc Pedrinho, DJ 900"],["Eminem"],["Sog, Ryan Castro, Peso Pluma"],["The Weeknd, Lana Del Rey"],["Bomba Est\u00ef\u00bf\u00bd\u00ef\u00bf\u00bdreo, Bad B"],["Keane"],["New West"],["Chino Pa ...
